# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanhB18059162022/MMRec/blob/dev/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## prevent timeout
# ```javascript
# function ClickConnect(){
# console.log("Working");
# document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
# }
# const inter = setInterval(ClickConnect,60000)
# ```
# ## undo
# ```javascript
# clearInterval(inter)
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install lmdb
# Out:
# Collecting lmdb
#   Downloading lmdb-1.8.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.4 kB)
# Downloading lmdb-1.8.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 10.2 MB/s eta 0:00:00
# Installing collected packages: lmdb
# Successfully installed lmdb-1.8.1

# %%
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-$(python -c "import torch;print(torch.__version__)").html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcu128/torch_scatter-2.1.2%2Bpt210cu128-cp312-cp312-linux_x86_64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 115.1 MB/s eta 0:00:00
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.1.2+pt210cu128

# %%
import os

# %%
PATH = "/content/drive/MyDrive/Colab Notebooks/CTH001/MMRec"

# %%
# !pip freeze > requirements.ggcolab.txt

# %%
# !cp "requirements.ggcolab.txt" "{PATH}/requirements.ggcolab.txt"

# %%
# !rm -rf MMRec

# %%
# !git clone https://github.com/ThanhB18059162022/MMRec.git -b dev
# Out:
# Cloning into 'MMRec'...
# remote: Enumerating objects: 591, done.
# remote: Counting objects: 100% (332/332), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 591 (delta 259), reused 209 (delta 193), pack-reused 259 (from 2)
# Receiving objects: 100% (591/591), 901.00 KiB | 3.72 MiB/s, done.
# Resolving deltas: 100% (333/333), done.

# %%
# Copy qua /content: Thư mục /content nằm trên ổ cứng SSD nội bộ của máy ảo Colab.
# Tốc độ đọc dữ liệu tại đây nhanh hơn gấp 10 - 50 lần so với đọc trực tiếp từ Drive.
# !cp -r "{PATH}/code/data/sports" "MMRec/data/sports"

# %%
os.chdir("MMRec/src")

# %%
import torch

print(f"Is CUDA available? {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"Current Device Index: {torch.cuda.current_device()}")
else:
    print("PyTorch is running on CPU.")
# Out:
# Is CUDA available? True
# GPU Name: Tesla T4
# Current Device Index: 0

# %%
# Thiết lập số epoch mong muốn tại đây
new_epochs = 10

# Sử dụng f-string để truyền biến vào lệnh sed
# !sed -i "s/epochs: [0-9]*/epochs: {new_epochs}/g" /content/MMRec/src/configs/overall.yaml

# Kiểm tra lại
print(f"Đã đổi epochs thành: {new_epochs}")
# !grep "epochs:" /content/MMRec/src/configs/overall.yaml
# Out:
# Đã đổi epochs thành: 10
# epochs: 10

# %%
# !pip install nvitop
# Out:
# Collecting nvitop
#   Downloading nvitop-1.6.2-py3-none-any.whl.metadata (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-ml-py<13.591.0a0,>=11.450.51 in /usr/local/lib/python3.12/dist-packages (from nvitop) (13.590.48)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.12/dist-packages (from nvitop) (5.9.5)
# Downloading nvitop-1.6.2-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: nvitop
# Successfully installed nvitop-1.6.2

# %%
# Xài terminal thay vì cell
# !nvitop
# Out:
# )07=Mon Mar 16 07:02:55 2026
# ╒═════════════════════════════════════════════════════════════════════════════╕
# │ NVITOP 1.6.2       Driver Version: 580.82.07      CUDA Driver Version: 13.0 │
# ├───────────────────────────────┬──────────────────────┬──────────────────────┤
# │ GPU  Name        Persistence-M│ Bus-Id        Disp.A │ Volatile Uncorr. ECC │
# │ Fan  Temp  Perf  Pwr:Usage/Cap│         Memory-Usage │ GPU-Util  Compute M. │
# ╞═══════════════════════════════╪══════════════════════╪══════════════════════╡
# │   0  Tesla T4             Off │ 00000000:00:04.0 Off │                    0 │
# │ N/A   34C   P8      12W / 70W │   2.88MiB / 15360MiB │      0%      Default │
# ╘═══════════════════════════════╧══════════════════════╧══════════════════════╛
# [ CPU: █████████████████████████████ MAX ]  ( Load Average:  2.34  0.70  0.29 )
# [ MEM: ███▉ 13.2%          USED: 1.36GiB ]  [ SWP: ▏ 0.0%                     ]
#
# ╒═════════════════════════════════════════════════════════════════════════════╕
# │ Processes:                                                root@27eb2c229d58 │
# │ GPU     PID      USER  GPU-MEM %SM %GMBW  %CPU  %MEM  TIME  COMMAND         │
# ╞═════════════════════════════════════════════════════════════════════════════╡
# │  No running processes found                                                 │
# ╘═════════════════════════════════════════════════════════════════════════════╛
# ERROR: Failed to initialize `curses` (curs_set() returned ERR)

# %%
# !python main.py -d sports -m SMORE
# Out:
# 16 Mar 07:59    INFO ██Server: 	27eb2c229d58
# 16 Mar 07:59    INFO ██Dir: 	/content/MMRec/src
#
# 16 Mar 07:59    INFO
# gpu_id=0
# use_gpu=True
# seed=[999]
# data_path=../data/
# inter_splitting_label=x_label
# filter_out_cod_start_users=True
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=True
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=5
# stopping_step=20
# train_batch_size=8192
# learner=adam
# learning_rate=0.001
# learning_rate_scheduler=[0.96, 50]
# eval_step=1
# training_neg_sample_num=1
# use_neg_sampling=True
# use_full_sampling=False
# NEG_PREFIX=neg__
# USER_ID_FIELD=userID
# ITEM_ID_FIELD=itemID
# TIME_FIELD=timestamp
# field_separator=
# metrics=['Recall', 'NDCG', 'Precision', 'MAP']
# topk=[5, 10, 20, 50]
# valid_metric=Recall@20
# eval_batch_size=4096
# use_raw_features=False
# max_txt_len=32
# max_img_size=256
# vocab_size=30522
# type_vocab_size=2
# hidden_size=4
# pad_token_id=0
# max_position_embeddings=512
# layer_norm_eps=1e-12
# hidden_dropout_prob=0.1
# end2end=False
# hyper_parameters=['seed', 'n_ui_layers', 'image_knn_k', 'text_knn_k', 'reg_weight', 'dropout_rate']
# inter_file_name=sports.inter
# vision_feature_file=image_feat.npy
# text_feature_file=text_feat.npy
# user_graph_dict_file=user_graph_dict.npy
# n_ui_layers=[4]
# n_layers=1
# lambda_coeff=0.9
# reg_weight=[0.0001]
# cl_loss=0.01
# temperature=0.2
# image_knn_k=[40]
# text_knn_k=[15]
# dropout_rate=[0.1]
# model=SMORE
# dataset=sports
# valid_metric_bigger=True
# device=cuda
#
#
# 16 Mar 07:59    INFO sports
# The number of users: 35598
# Average actions of users: 8.324540704533963
# The number of items: 18357
# Average actions of items: 16.142997221768262
# The number of inters: 296337
# The sparsity of the dataset: 99.95465195454304%
# 16 Mar 07:59    INFO
# ====Training====
# sports
# The number of users: 35598
# Average actions of users: 6.13542895668296
# The number of items: 18352
# Average actions of items: 11.901100697471666
# The number of inters: 218409
# The sparsity of the dataset: 99.96656806366236%
# 16 Mar 07:59    INFO
# ====Validation====
# sports
# The number of users: 35598
# Average actions of users: 1.0646384628349908
# The number of items: 13342
# Average actions of items: 2.840578623894469
# The number of inters: 37899
# The sparsity of the dataset: 99.99202039826986%
# 16 Mar 07:59    INFO
# ====Testing====
# sports
# The number of users: 35598
# Average actions of users: 1.1244732850160122
# The number of items: 13738
# Average actions of items: 2.9137429028970736
# The number of inters: 40029
# The sparsity of the dataset: 99.99181486908563%
# 16 Mar 07:59    INFO
#
# =================================
#
#
# 16 Mar 07:59    INFO =========1/1: Parameters:['seed', 'n_ui_layers', 'image_knn_k', 'text_knn_k', 'reg_weight', 'dropout_rate']=(999, 4, 40, 15, 0.0001, 0.1)=======
# /content/MMRec/src/models/smore.py:167: RuntimeWarning: divide by zero encountered in power
#   d_inv = np.power(rowsum, -0.5).flatten()
# /content/MMRec/src/models/smore.py:186: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:654.)
#   return torch.sparse.FloatTensor(indices, values, shape)
# 16 Mar 08:00    INFO SMORE(
#   (dropout): Dropout(p=0.1, inplace=False)
#   (user_embedding): Embedding(35598, 64)
#   (item_id_embedding): Embedding(18357, 64)
#   (image_embedding): Embedding(1000, 2048)
#   (text_embedding): Embedding(18357, 384)
#   (image_trs): Linear(in_features=2048, out_features=64, bias=True)
#   (text_trs): Linear(in_features=384, out_features=64, bias=True)
#   (softmax): Softmax(dim=-1)
#   (query_v): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=64, bias=False)
#   )
#   (query_t): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=64, bias=False)
#   )
#   (gate_v): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): Sigmoid()
#   )
#   (gate_t): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): Sigmoid()
#   )
#   (gate_f): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): Sigmoid()
#   )
#   (gate_image_prefer): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): Sigmoid()
#   )
#   (gate_text_prefer): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): Sigmoid()
#   )
#   (gate_fusion_prefer): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): Sigmoid()
#   )
# )
# Trainable parameters: 12747654
# Traceback (most recent call last):
#   File "/content/MMRec/src/main.py", line 27, in <module>
#     quick_start(model=args.model, dataset=args.dataset, config_dict=config_dict, save_model=True)
#   File "/content/MMRec/src/utils/quick_start.py", line 81, in quick_start
#     best_valid_score, best_valid_result, best_test_upon_valid = trainer.fit(train_data, valid_data=valid_data, test_data=test_data, saved=save_model)
#                                                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/MMRec/src/common/trainer.py", line 241, in fit
#     train_loss, _ = self._train_epoch(train_data, epoch_idx)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/MMRec/src/common/trainer.py", line 153, in _train_epoch
#     losses = loss_func(interaction)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/MMRec/src/models/smore.py", line 321, in calculate_loss
#     ua_embeddings, ia_embeddings, side_embeds, content_embeds = self.forward(
#                                                                 ^^^^^^^^^^^^^
#   File "/content/MMRec/src/models/smore.py", line 215, in forward
#     image_conv, text_conv, fusion_conv = self.spectrum_convolution(image_feats, text_feats)
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/MMRec/src/models/smore.py", line 204, in spectrum_convolution
#     fusion_conv = torch.fft.irfft(text_fft * image_fft * fusion_complex_weight, n=text_embeds.shape[1], dim=1, norm='ortho')
#                                   ~~~~~~~~~^~~~~~~~~~~
# RuntimeError: The size of tensor a (18357) must match the size of tensor b (1000) at non-singleton dimension 0
