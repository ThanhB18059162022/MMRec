# %% [markdown]
# # https://github.com/enoche/MMRec.git
# ## forked https://github.com/ThanhB18059162022/MMRec.git

# %% [markdown]
# ## Kéo code về lưu

# %%
# !rm -rf MMRec

# %%
# !git clone -b dev https://github.com/ThanhB18059162022/MMRec.git
# Out:
# Cloning into 'MMRec'...
# remote: Enumerating objects: 488, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 488 (delta 185), reused 175 (delta 175), pack-reused 259 (from 2)
# Receiving objects: 100% (488/488), 699.97 KiB | 3.00 MiB/s, done.
# Resolving deltas: 100% (259/259), done.

# %%
# !cp -r MMRec "/content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code"

# %%
# !zip -r "/content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code.zip" "/content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code"
# Out:
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code/ (stored 0%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code/.git/ (stored 0%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code/.git/branches/ (stored 0%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code/.git/hooks/ (stored 0%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code/.git/hooks/update.sample (deflated 68%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/code/.git/hooks/post-update.sample (deflated 27%)
# ...

# %% [markdown]
# ## Lấy dữ liệu trong code

# %%
# https://drive.google.com/drive/folders/1Fk21441EO1l7wgOOARh2thu4FjgtKWQp

# %%
# !gdown --folder https://drive.google.com/drive/folders/13cBy1EA_saTUuXxVllKgtfci2A09jyaG
# Out:
# Retrieving folder contents
# Retrieving folder 1Fk21441EO1l7wgOOARh2thu4FjgtKWQp baby
# Processing file 1i2IB2bdxu_jMSxr2IvZ04MG54ySgI2JN baby.inter
# Processing file 1eagqR_X3H6zFjw1lFXjLLX7fB7AoTxtG i_id_mapping.csv
# Processing file 103Pxo73naIwmKI6CR71d3t7A5k-lpk9c image_feat.npy
# Processing file 1EP-Ro9Lq-RQV_Urrh8Xpa-mvr635tytj text_feat.npy
# Processing file 1IujVzYfihippYT36v16aNLPpKT4ELwyK u_id_mapping.csv
# Processing file 1e1BYjeBmJqhwduOjdTfBbJLZpKiHdm7A user_graph_dict.npy
# Retrieving folder 1Suzbyc26BEPPLQJzT_5-EDz_wMf6r7u6 clothing
# Processing file 1ys0duZPKEhiTqhW7rL0tfNLJSq_lWdHl clothing.inter
# Processing file 1lqBx5UYkMWHwY5m7FJgN0v11YhYUdKXM i_id_mapping.csv
# Processing file 1n7D9Bsbi7ooVmVeBH-hCY7rcYQaUjGFQ image_feat.npy
# Processing file 1TQNbtceIaBjoqmXwVZQkb17mo7VS15vy text_feat.npy
# Processing file 15gE1YBnRfVRWuMXpPRzSSrVss3YQceOu u_id_mapping.csv
# Retrieving folder 1vzC5e1Mpc6f6-61QKjiSeO15BfXjYLQI elec
# ...

# %%
# !rm -rf "/content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data"

# %%
# !mv "./BM3" "/content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3"

# %%
# !zip -r "/content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3.zip" "/content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3"
# Out:
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3/ (stored 0%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3/baby/ (stored 0%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3/baby/baby.inter (deflated 75%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3/baby/i_id_mapping.csv (deflated 57%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3/baby/image_feat.npy (deflated 85%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3/baby/text_feat.npy (deflated 7%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3/baby/u_id_mapping.csv (deflated 41%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3/baby/user_graph_dict.npy (deflated 81%)
#   adding: content/drive/MyDrive/Colab Notebooks/CTH001/MMRec/data/BM3/clothing/ (stored 0%)
# ...
