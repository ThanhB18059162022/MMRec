# %% [markdown]
# - https://amazon-reviews-2023.github.io/

# %%
import os
import numpy as np
import pandas as pd

# %%
PATH = "../../data/2023"

# %% [markdown]
# ## Tải hết dữ liệu

# %%
os.makedirs(os.path.join(PATH, "Baby_Products_meta_images"), exist_ok=True)

# %%
# Đảm bảo sử dụng index toàn cục bằng cách không thiết lập index=False
reader = pd.read_json(os.path.join(PATH, "meta_Baby_Products.jsonl"), lines=True, chunksize=50_000)

cnt = 0
for chunk_idx, df in enumerate(reader):
    cnt += 1
    print(chunk_idx, cnt)
    # 1. Bỏ qua các chunk trước start_chunk
    if cnt == 5:
        print("last")
        break


    # print(f"Processing chunk {chunk_idx} with {len(df)} records")
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5
# last

# %%
df.iloc[0]['images']
# Out:
# [{'thumb': 'https://m.media-amazon.com/images/I/41+SfWrfPkL._SS40_.jpg',
#   'large': 'https://m.media-amazon.com/images/I/41+SfWrfPkL.jpg',
#   'variant': 'MAIN',
#   'hi_res': 'https://m.media-amazon.com/images/I/6173uqKVzfL._SL1300_.jpg'},
#  {'thumb': 'https://m.media-amazon.com/images/I/41UaLOOlyFL._SS40_.jpg',
#   'large': 'https://m.media-amazon.com/images/I/41UaLOOlyFL.jpg',
#   'variant': 'PT01',
#   'hi_res': 'https://m.media-amazon.com/images/I/61yMQ5y6OAL._SL1300_.jpg'},
#  {'thumb': 'https://m.media-amazon.com/images/I/41cldZMHt7L._SS40_.jpg',
#   'large': 'https://m.media-amazon.com/images/I/41cldZMHt7L.jpg',
#   'variant': 'PT02',
#   'hi_res': 'https://m.media-amazon.com/images/I/61oyGcdrfqL._SL1300_.jpg'},
#  {'thumb': 'https://m.media-amazon.com/images/I/4178ufyvQ1L._SS40_.jpg',
#   'large': 'https://m.media-amazon.com/images/I/4178ufyvQ1L.jpg',
#   'variant': 'PT03',
#   'hi_res': 'https://m.media-amazon.com/images/I/614R+LDIVrL._SL1300_.jpg'},
#  {'thumb': 'https://m.media-amazon.com/images/I/41S9e4q39BL._SS40_.jpg',
#   'large': 'https://m.media-amazon.com/images/I/41S9e4q39BL.jpg',
#   'variant': 'PT04',
#   'hi_res': 'https://m.media-amazon.com/images/I/61eW+yBOYmL._SL1300_.jpg'},
#  {'thumb': 'https://m.media-amazon.com/images/I/51JzpsaNU3L._SS40_.jpg',
#   'large': 'https://m.media-amazon.com/images/I/51JzpsaNU3L.jpg',
#   'variant': 'PT05',
#   'hi_res': 'https://m.media-amazon.com/images/I/71BYjTlHsmL._SL1300_.jpg'},
#  {'thumb': 'https://m.media-amazon.com/images/I/41BH+GcSgrL._SS40_.jpg',
#   'large': 'https://m.media-amazon.com/images/I/41BH+GcSgrL.jpg',
#   'variant': 'PT06',
#   'hi_res': 'https://m.media-amazon.com/images/I/61zMzy8hUsL._SL1300_.jpg'},
#  {'thumb': 'https://m.media-amazon.com/images/I/417DeemviZL._SS40_.jpg',
#   'large': 'https://m.media-amazon.com/images/I/417DeemviZL.jpg',
#   'variant': 'PT07',
#   'hi_res': 'https://m.media-amazon.com/images/I/61Mx8rOdw4L._SL1300_.jpg'},
#  {'thumb': 'https://m.media-amazon.com/images/I/51-YuXMTGQL._SS40_.jpg',
#   'large': 'https://m.media-amazon.com/images/I/51-YuXMTGQL.jpg',
#   'variant': 'PT08',
#   'hi_res': 'https://m.media-amazon.com/images/I/61xMzJiFl1L._SL1000_.jpg'}]

# %% [markdown]
# ### Song song

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import os, json, ast, time, shutil, random, logging, requests
import numpy as np
import pandas as pd
from urllib.parse import urlparse

# =========================
# CONFIG
# =========================
MAX_THREADS = 30        # Số luồng SONG SONG cho CÁC SẢN PHẨM (product)

URL_PRIORITIES = ['hi_res', 'large', 'thumb']
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
    'Accept': 'image/webp,image/*,*/*;q=0.8'
}

# 🆕 CẤU HÌNH RATE LIMITING
MIN_DOWNLOAD_DELAY = 1.0 
MAX_DOWNLOAD_DELAY = 2.0 


# =========================
# Logging – DEBUG vào File, ERROR ra Console
# =========================
import logging # Đảm bảo import logging

def setup_logging(log_file):
    # 1. Khởi tạo Logger chính
    logger = logging.getLogger("ImageDownloader")
    
    if not logger.handlers: 
        # Đặt mức độ logger chính là DEBUG (thấp nhất) để bắt được tất cả các thông báo
        logger.setLevel(logging.DEBUG)
        
        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

        # --- 2. File Handler (Ghi vào File) ---
        file_handler = logging.FileHandler(log_file, 'a', 'utf-8')
        # Đặt mức độ log cho File Handler là DEBUG
        file_handler.setLevel(logging.DEBUG) 
        file_handler.setFormatter(formatter)
        logger.addHandler(file_handler)
        
        # --- 3. Console Handler (Ghi ra Console/Màn hình) ---
        # Sử dụng StreamHandler để ghi ra stdout (console)
        console_handler = logging.StreamHandler()
        # Đặt mức độ log cho Console Handler là ERROR
        console_handler.setLevel(logging.ERROR) 
        console_handler.setFormatter(formatter)
        logger.addHandler(console_handler)
    
    return logger

# =========================
# Parse image list (Giữ nguyên)
# =========================
def parse_image_list(images_data):
    if isinstance(images_data, list):
        return images_data
    if isinstance(images_data, str):
        try:
            return ast.literal_eval(images_data)
        except (ValueError, SyntaxError):
            try:
                clean = images_data.replace("'", '"').replace("None", "null").replace("False", "false").replace("True", "true")
                return json.loads(clean)
            except:
                pass
    return None


# # =========================
# Download 1 image với retry (Xử lý 404 và Rate Limiting)
# =========================
def download_one_image(url, save_path, idx, logger, max_retry=3):
    logger.debug(f"[{idx}] Start download: {url}")
    
    for attempt in range(1, max_retry + 1):
        
        # RATE LIMITING: Độ trễ ngẫu nhiên trước lần thử đầu tiên
        if attempt == 1:
            time.sleep(random.uniform(MIN_DOWNLOAD_DELAY, MAX_DOWNLOAD_DELAY))
        
        try:
            resp = requests.get(url, headers=HEADERS, timeout=10)
            
            # XỬ LÝ LỖI VĨNH VIỄN 404
            if resp.status_code == 404:
                logger.error(f"[{idx}] FAILED FINAL (404 Not Found): {url}")
                return False # Bỏ qua retry nếu gặp 404
            
            # Kiểm tra các lỗi khác (4xx, 5xx)
            resp.raise_for_status()
            
            # Tải thành công
            with open(save_path, "wb") as f:
                f.write(resp.content)
            
            # 🆕 LOG THÔNG BÁO TẢI THÀNH CÔNG
            logger.info(f"[{idx}] SUCCESS: {url}")
            return True
            
        except Exception as e:
            logger.error(f"[{idx}] attempt {attempt}/{max_retry} → {url} : {e}")
            if attempt == max_retry:
                logger.error(f"[{idx}] FAILED FINAL: {url}")
                return False
            
            # Độ trễ tăng dần cho retry (Exponential Backoff)
            retry_delay = (2 ** (attempt - 1)) + random.uniform(0, 0.5)
            time.sleep(retry_delay)

# =========================
# Submit download tasks cho 1 product (row) – CHẠY TUẦN TỰ CHO CÁC ẢNH
# =========================
# Đã loại bỏ tham số 'executor'
def download_row_images(idx, images_data, output_dir, logger):
    if images_data is None or images_data is np.nan:
        return True # Hoàn thành xử lý nếu không có dữ liệu

    if not isinstance(images_data, list):
        images_data = parse_image_list(images_data)

    if not images_data:
        return True # Hoàn thành xử lý nếu danh sách ảnh rỗng

    # Đảm bảo thư mục sản phẩm tồn tại
    product_dir = os.path.join(output_dir, str(idx))
    os.makedirs(product_dir, exist_ok=True) 

    success_count = 0
    
    # Vòng lặp tuần tự cho từng ảnh trong sản phẩm
    for i, img in enumerate(images_data):
        url = next((img.get(p) for p in URL_PRIORITIES if img.get(p)), None)
        
        if not url:
            continue
            
        name = img.get("variant", f"img_{i:02d}")
        name = name.replace("/", "_").replace("\\", "_").replace(":", "_").replace("*", "_").replace("?", "_")
        
        ext = os.path.splitext(urlparse(url).path)[1] or ".jpg"
        if not ext.startswith("."):
             ext = "." + ext

        save_path = os.path.join(product_dir, f"{name}{ext}")
        
        # CHỈ TẢI NẾU TỆP ĐÍCH CHƯA TỒN TẠI (Resume)
        if os.path.exists(save_path):
            success_count += 1
            continue

        # Gọi download_one_image trực tiếp (chạy tuần tự)
        if download_one_image(url, save_path, idx, logger):
            success_count += 1
    
    # Trả về True/False để cho biết sản phẩm này đã được xử lý xong
    return success_count == len(images_data)


# =========================
# Kiểm tra sự tồn tại và số lượng ảnh đã hoàn thành
# =========================
def is_product_complete(idx, images_data, chunk_dir):
    """Kiểm tra nếu thư mục sản phẩm tồn tại và có đủ số lượng ảnh."""
    product_dir = os.path.join(chunk_dir, str(idx))

    # 1. Kiểm tra nếu không có dữ liệu ảnh (được coi là hoàn thành)
    if images_data is None or images_data is np.nan:
        return True
    
    if not isinstance(images_data, list):
        images_data = parse_image_list(images_data)
    
    if not images_data:
        return True # Không có ảnh để tải

    expected_count = len(images_data)
    
    # 2. Kiểm tra nếu folder không tồn tại, chắc chắn chưa hoàn thành
    if not os.path.exists(product_dir):
        return False
    
    # 3. Kiểm tra số lượng file trong folder
    actual_count = len(os.listdir(product_dir))
    
    # Lưu ý: Việc kiểm tra số lượng file không đảm bảo tên file khớp, 
    # nhưng đây là cách kiểm tra nhanh (quick check)
    return actual_count >= expected_count


# =========================
# Process 1 chunk (ĐÃ SỬA ĐỔI ĐỂ KIỂM TRA ĐỦ HÌNH TRƯỚC VÀ DÙNG LOG)
# =========================
def process_one_chunk(chunk_idx, df, output_root, log_file):
    # Khởi tạo logger cho chunk này
    logger = setup_logging(log_file) 
    
    chunk_dir = os.path.join(output_root, f"chunk_{chunk_idx}")
    os.makedirs(chunk_dir, exist_ok=True)
    
    all_tasks = []
    
    # Khởi tạo ThreadPoolExecutor: MAX_THREADS là số lượng SẢN PHẨM được xử lý song song
    with ThreadPoolExecutor(max_workers=MAX_THREADS) as pool:
        
        # 1. Lặp qua TỪNG SẢN PHẨM (tuần tự) và submit tác vụ xử lý sản phẩm
        for idx, row in df.iterrows():
            
            # KIỂM TRA NẾU SẢN PHẨM ĐÃ HOÀN THÀNH TẢI XUỐNG
            if is_product_complete(idx, row["images"], chunk_dir):
                logger.debug(f"[{idx}] Folder tồn tại và đủ hình, bỏ qua tạo task.")
                continue # BỎ QUA tạo task nếu đã hoàn thành
            
            # Gửi toàn bộ việc xử lý một sản phẩm (tải ảnh tuần tự) vào một luồng
            future = pool.submit(download_row_images, idx, row["images"], chunk_dir, logger)
            all_tasks.append(future)
            
        # 2. Đợi TẤT CẢ sản phẩm hoàn thành
        # SỬ DỤNG logger.info THAY CHO print
        logger.info(f"Chunk {chunk_idx}: Total {len(all_tasks)} product tasks submitted. Waiting...")
        
        completed_products = 0
        for future in as_completed(all_tasks):
            completed_products += 1
            try:
                future.result() 
            except Exception as e:
                logger.error(f"A product processing task failed unexpectedly: {e}")

    return chunk_idx


# =========================
# Main – chunk tuần tự, sản phẩm song song (ĐÃ THÊM end_chunk)
# =========================
def process_chunks(json_file, chunk_size=10, output_root="download_chunks",
                   log_file="error.log", start_chunk=0, end_chunk=None): # <--- THÊM end_chunk
    
    # Setup logger ở đây để ghi các thông báo tổng quan của hàm main
    main_logger = setup_logging(log_file)

    # Đảm bảo sử dụng index toàn cục bằng cách không thiết lập index=False
    reader = pd.read_json(json_file, lines=True, chunksize=chunk_size)

    for chunk_idx, df in enumerate(reader):
        
        # 1. Bỏ qua các chunk trước start_chunk
        if chunk_idx < start_chunk:
            main_logger.info(f"⏭ Skip chunk {chunk_idx}")
            continue

        # 2. DỪNG LẠI nếu đạt đến end_chunk (nếu được chỉ định)
        # Sử dụng > end_chunk vì chúng ta muốn xử lý chunk_idx == end_chunk
        if end_chunk is not None and chunk_idx > end_chunk:
            main_logger.info(f"🛑 Reached end_chunk {end_chunk}. Stopping.")
            break 

        main_logger.info(f"▶ Processing chunk {chunk_idx} (rows {df.index.min()} to {df.index.max()}) ...")
        
        start_time = time.time()
        # Trong process_chunks, chúng ta không cần truyền logger vì process_one_chunk tự setup
        idx = process_one_chunk(chunk_idx, df, output_root, log_file) 
        end_time = time.time()
        
        main_logger.info(f"✔ Chunk {idx} done in {end_time - start_time:.2f}s")

    main_logger.info("🎉 ALL DONE")

# %%
filepath = os.path.join(PATH, "meta_Baby_Products.jsonl")

process_chunks(filepath, chunk_size=50_000, output_root=os.path.join(PATH, "Baby_Products_meta_images"),
               log_file=os.path.join(PATH, "download_errors.log"),
               start_chunk=5, end_chunk=5)

# %%
import os
import tarfile

images_root = os.path.join(PATH, "Baby_Products_meta_images")
output_dir = os.path.join(PATH, "compressed_chunks")

os.makedirs(output_dir, exist_ok=True)

chunk_folders = sorted(os.listdir(images_root), key=lambda x: int(x.split('_')[1]))
chunk_folders
# Out:
# ['chunk_2', 'chunk_4']

# %%
# Compress only the first 10 chunk directories to .tar.gz
for chunk_folder in chunk_folders[1:]:
    chunk_path = os.path.join(images_root, chunk_folder)
    
    if os.path.isdir(chunk_path):
        output_file = os.path.join(output_dir, f"{chunk_folder}.tar.gz")
        
        # Create tar.gz archive
        with tarfile.open(output_file, "w:gz") as tar:
            tar.add(chunk_path, arcname=chunk_folder)
        
        print(f"Compressed: {output_file}")

print("Chunks compressed successfully!")
# Out:
# Compressed: ./data\compressed_chunks\chunk_4.tar.gz
# Chunks compressed successfully!

# %% [markdown]
# ## Tải lại dữ liệu thiếu

# %%
df = pd.read_parquet(os.path.join(PATH, "step0_clean_data", "df_meta.with_image.parquet"))

# %%
df_miss_image = df[df["has_image"] == False].copy()

# %%
df_miss_image.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 37 entries, 3223 to 35989
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   main_category    37 non-null     str
#  1   title            37 non-null     str
#  2   average_rating   37 non-null     float64
#  3   rating_number    37 non-null     int64
#  4   features         37 non-null     object
#  5   description      37 non-null     object
#  6   price            6 non-null      float64
#  7   images           37 non-null     object
#  8   videos           37 non-null     object
#  9   store            35 non-null     str
#  10  categories       37 non-null     object
#  11  details          37 non-null     object
#  12  asin             37 non-null     str
#  13  bought_together  0 non-null      float64
#  14  subtitle         0 non-null      float64
#  15  author           0 non-null      object
#  16  has_image        37 non-null     bool
# dtypes: bool(1), float64(4), int64(1), object(7), str(4)
# memory usage: 9.2+ KB

# %%
df_miss_image.shape
# Out:
# (37, 17)

# %%
df_miss_image.head(3)
# Out:
#      main_category                                              title  \
# 3223          Baby                        Little Green Pouch (4 Pack)
# 4615          Baby  Joovy Caboose Ultralight Stand On Tandem Stroller
# 9083          Baby                                   Cumbor Baby Gate
#
#       average_rating  rating_number  \
# 3223             3.1             21
# 4615             3.0             57
# 9083             4.3             92
#
#                                                features  \
# 3223                                                 []
# 4615                                         [Neoprene]
# 9083  [All Gate support both presssure and drill ins...
#
#                                             description  price  \
# 3223                                                 []    NaN
# 4615  [From the Manufacturer, Joovy Caboose Ultralig...    NaN
# 9083  [All Gate support both presssure and drill ins...    NaN
#
#                                                  images  \
# 3223  [{'hi_res': None, 'large': 'https://m.media-am...
# 4615  [{'hi_res': 'https://m.media-amazon.com/images...
# 9083  [{'hi_res': None, 'large': 'https://m.media-am...
#
#                                                  videos   store  \
# 3223                                                 []     LGP
# 4615                                                 []   Joovy
# 9083  [{'title': 'This gate is chic, easy to assembl...  Cumbor
#
#                                              categories  \
# 3223                                                 []
# 4615  [Baby Products, Strollers & Accessories, Strol...
# 9083  [Baby Products, Safety, Gates & Gate Extension...
#
#                                                 details        asin  \
# 3223  {'': None, 'ABPA Partslink Number': None, 'AC ...  B009WUPGQC
# 4615  {'': None, 'ABPA Partslink Number': None, 'AC ...  B00192LH3C
# 9083  {'': None, 'ABPA Partslink Number': None, 'AC ...  B09KRQ18Z1
#
#       bought_together  subtitle author  has_image
# 3223              NaN       NaN   None      False
# 4615              NaN       NaN   None      False
# 9083              NaN       NaN   None      False

# %%
df_miss_image["images"]
# Out:
# 3223     [{'hi_res': None, 'large': 'https://m.media-am...
# 4615     [{'hi_res': 'https://m.media-amazon.com/images...
# 9083     [{'hi_res': None, 'large': 'https://m.media-am...
# 9554     [{'hi_res': None, 'large': 'https://m.media-am...
# 9866     [{'hi_res': 'https://m.media-amazon.com/images...
# 10670    [{'hi_res': None, 'large': 'https://m.media-am...
# 11188    [{'hi_res': None, 'large': 'https://m.media-am...
# 12545    [{'hi_res': 'https://m.media-amazon.com/images...
# 13840    [{'hi_res': 'https://m.media-amazon.com/images...
# 14773    [{'hi_res': None, 'large': 'https://m.media-am...
# 15009    [{'hi_res': 'https://m.media-amazon.com/images...
# 15394    [{'hi_res': 'https://m.media-amazon.com/images...
# 15950    [{'hi_res': 'https://m.media-amazon.com/images...
# 16854    [{'hi_res': 'https://m.media-amazon.com/images...
# 16949    [{'hi_res': None, 'large': 'https://m.media-am...
# 17718    [{'hi_res': 'https://m.media-amazon.com/images...
# 20242    [{'hi_res': 'https://m.media-amazon.com/images...
# 20896    [{'hi_res': 'https://m.media-amazon.com/images...
# 21348    [{'hi_res': None, 'large': 'https://m.media-am...
# 21456    [{'hi_res': 'https://m.media-amazon.com/images...
# 22179    [{'hi_res': None, 'large': 'https://m.media-am...
# 23087    [{'hi_res': None, 'large': 'https://m.media-am...
# 23735    [{'hi_res': 'https://m.media-amazon.com/images...
# 24992    [{'hi_res': 'https://m.media-amazon.com/images...
# 25596    [{'hi_res': 'https://m.media-amazon.com/images...
# 27919    [{'hi_res': None, 'large': 'https://m.media-am...
# 29392    [{'hi_res': None, 'large': 'https://m.media-am...
# 30097    [{'hi_res': None, 'large': 'https://m.media-am...
# 32380    [{'hi_res': None, 'large': 'https://m.media-am...
# 32535    [{'hi_res': None, 'large': 'https://m.media-am...
# 32577    [{'hi_res': None, 'large': 'https://m.media-am...
# 32987    [{'hi_res': None, 'large': 'https://m.media-am...
# 33305    [{'hi_res': None, 'large': 'https://m.media-am...
# 34249    [{'hi_res': None, 'large': 'https://m.media-am...
# 35987    [{'hi_res': 'https://m.media-amazon.com/images...
# 35988    [{'hi_res': 'https://m.media-amazon.com/images...
# 35989    [{'hi_res': 'https://m.media-amazon.com/images...
# Name: images, dtype: object

# %%
def parse_image_list(images_data):
    if isinstance(images_data, (list, tuple)):
        return list(images_data)
    if isinstance(images_data, np.ndarray):
        return images_data.tolist()
    if isinstance(images_data, str):
        try:
            return ast.literal_eval(images_data)
        except (ValueError, SyntaxError):
            try:
                clean = images_data.replace("'", '"').replace("None", "null").replace("False", "false").replace("True", "true")
                return json.loads(clean)
            except Exception:
                return None
    return None


def is_valid_image_url(url):
    return isinstance(url, str) and url.strip() and not url.lower().endswith(".gif")


def get_image_urls(images):
    images = parse_image_list(images)
    if not images:
        return []

    def extract_urls(item):
        if not isinstance(item, dict):
            return []
        urls = []
        for key in ("hi_res", "large", "url", "thumb"):
            url = item.get(key)
            if is_valid_image_url(url):
                urls.append(url.strip())
        return urls

    main_urls = []
    other_urls = []
    for item in images:
        current_urls = extract_urls(item)
        if isinstance(item, dict) and item.get("variant") == "MAIN":
            main_urls.extend(current_urls)
        else:
            other_urls.extend(current_urls)

    ordered_urls = []
    for url in main_urls + other_urls:
        if url not in ordered_urls:
            ordered_urls.append(url)
    return ordered_urls


def get_image_url(images):
    urls = get_image_urls(images)
    return urls[0] if urls else None

# %%
df_miss_image["image_url"] = df_miss_image["images"].apply(get_image_url)

# %%
df_miss_image["image_url"]
# Out:
# 3223                                                   NaN
# 4615     https://m.media-amazon.com/images/I/61qBur+rN-...
# 9083                                                   NaN
# 9554                                                   NaN
# 9866     https://m.media-amazon.com/images/I/81sApJO6FH...
# 10670                                                  NaN
# 11188                                                  NaN
# 12545    https://m.media-amazon.com/images/I/61WZ2NcbDZ...
# 13840    https://m.media-amazon.com/images/I/61ch3rYOGe...
# 14773                                                  NaN
# 15009    https://m.media-amazon.com/images/I/61p7Wpo6Nj...
# 15394    https://m.media-amazon.com/images/I/91Po8VMJBx...
# 15950    https://m.media-amazon.com/images/I/91VWwNO-RI...
# 16854    https://m.media-amazon.com/images/I/815MNoU381...
# 16949                                                  NaN
# 17718    https://m.media-amazon.com/images/I/71m3bv0RyB...
# 20242    https://m.media-amazon.com/images/I/71V2fdrG9M...
# 20896    https://m.media-amazon.com/images/I/8167l7lxHY...
# 21348                                                  NaN
# 21456    https://m.media-amazon.com/images/I/71DTVWr3AO...
# 22179                                                  NaN
# 23087                                                  NaN
# 23735    https://m.media-amazon.com/images/I/71o-E7OXvk...
# 24992    https://m.media-amazon.com/images/I/716cnl+E3I...
# 25596    https://m.media-amazon.com/images/I/71i655bHDC...
# 27919                                                  NaN
# 29392                                                  NaN
# 30097    https://m.media-amazon.com/images/I/415DfCoDlV...
# 32380                                                  NaN
# 32535                                                  NaN
# 32577                                                  NaN
# 32987                                                  NaN
# 33305                                                  NaN
# 34249                                                  NaN
# 35987    https://m.media-amazon.com/images/I/71UgfvS4gJ...
# 35988    https://m.media-amazon.com/images/I/71vHZNtKL1...
# 35989    https://m.media-amazon.com/images/I/61311d72rE...
# Name: image_url, dtype: str

# %%
df_miss_image["has_retry_image"] = df_miss_image["image_url"].notna()

# %%
df_miss_image["image_url"].to_csv(os.path.join(PATH, "step0_clean_data", "df_meta_image_urls.csv"), index=False)

# %%
df_miss_image.to_parquet(os.path.join(PATH, "step0_clean_data", "df_miss_image.parquet"), index=False)

# %%
df_miss_image[df_miss_image["has_retry_image"] == False]["images"].iloc[0]
# Out:
# array([{'hi_res': None, 'large': 'https://m.media-amazon.com/images/I/01RmK+J4pJL.gif', 'thumb': 'https://m.media-amazon.com/images/I/01RmK+J4pJL._SS40_.gif', 'variant': 'MAIN'}],
#       dtype=object)

# %%
df_miss_image["has_retry_image"]
# Out:
# 3223     False
# 4615      True
# 9083     False
# 9554     False
# 9866      True
# 10670    False
# 11188    False
# 12545     True
# 13840     True
# 14773    False
# 15009     True
# 15394     True
# 15950     True
# 16854     True
# 16949    False
# 17718     True
# 20242     True
# 20896     True
# 21348    False
# 21456     True
# 22179    False
# 23087    False
# 23735     True
# 24992     True
# 25596     True
# 27919    False
# 29392    False
# 30097     True
# 32380    False
# 32535    False
# 32577    False
# 32987    False
# 33305    False
# 34249    False
# 35987     True
# 35988     True
# 35989     True
# Name: has_retry_image, dtype: bool

# %%
import requests
from urllib.parse import urlparse

HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
    'Accept': 'image/webp,image/*,*/*;q=0.8'
}

missing = df_miss_image[df_miss_image["has_retry_image"] == True].copy()
print(f"Missing rows: {len(missing)}")
missing["image_urls"] = missing["images"].apply(get_image_urls)
missing = missing[missing["image_urls"].map(bool)]
print(f"Missing rows with valid image_urls: {len(missing)}")

output_dir = os.path.join(PATH, "step0_clean_data", "missing_images")
os.makedirs(output_dir, exist_ok=True)

for idx, row in missing.iterrows():
    urls = row["image_urls"]
    asin = str(row["asin"]).strip() if pd.notna(row["asin"]) else None
    if not asin:
        print(f"Skip row {idx} because ASIN is missing")
        continue

    saved = False
    for url in urls:
        ext = os.path.splitext(urlparse(url).path)[1]
        if not ext or len(ext) > 10:
            ext = ".jpg"
        filename = f"{asin}{ext}"
        save_path = os.path.join(output_dir, filename)
        if os.path.exists(save_path):
            saved = True
            break
        try:
            resp = requests.get(url, headers=HEADERS, timeout=15)
            if resp.status_code == 404:
                print(f"404, try next URL for asin={asin}: {url}")
                continue
            resp.raise_for_status()
            with open(save_path, "wb") as f:
                f.write(resp.content)
            saved = True
            break
        except Exception as e:
            print(f"Failed to download asin={asin} url={url}: {e}")
            continue

    if not saved:
        print(f"No valid URL succeeded for asin={asin}")

print(f"Done. Downloaded files to {output_dir}")
# Out:
# Missing rows: 19
# Missing rows with valid image_urls: 19
# 404, try next URL for asin=B086GVZLPV: https://m.media-amazon.com/images/I/71V2fdrG9ML._AC_SL1500_.jpg
# 404, try next URL for asin=B086GVZLPV: https://m.media-amazon.com/images/I/516GSMy9HIL._AC_.jpg
# 404, try next URL for asin=B086GVZLPV: https://m.media-amazon.com/images/I/516GSMy9HIL._AC_US75_.jpg
# Done. Downloaded files to ../../data/2023\step0_clean_data\missing_images

# %%
df_miss_image[df_miss_image["asin"] == "B086GVZLPV"]
# Out:
#       main_category                                              title  \
# 20242          Baby  Bedtime Originals Rainbow Unicorn 3Piece Crib ...
#
#        average_rating  rating_number  \
# 20242             4.8            598
#
#                                                 features  \
# 20242  [Cotton/ Polyester, Imported, Included is one ...
#
#                                              description  price  \
# 20242  [Decorate your little one's sleep space with t...   52.7
#
#                                                   images  \
# 20242  [{'hi_res': 'https://m.media-amazon.com/images...
#
#                                                   videos              store  \
# 20242  [{'title': 'crib Bedding sets for girls', 'url...  Bedtime Originals
#
#                                               categories  \
# 20242  [Baby Products, Nursery, Bedding, Baby Bedding...
#
#                                                  details        asin  \
# 20242  {'': None, 'ABPA Partslink Number': None, 'AC ...  B086GVZLPV
#
#        bought_together  subtitle author  has_image  \
# 20242              NaN       NaN   None      False
#
#                                                image_url  has_retry_image
# 20242  https://m.media-amazon.com/images/I/71V2fdrG9M...             True
